# %%
import numpy as np

from sklearn.tree import DecisionTreeClassifier

# %%
data = list()
with open("../pcap/onu.bin", "rb") as file:
    while 
    l_bytes = file.read(4) # bytes for the length of the packet
    l = int.from_bytes(l_bytes, byteorder="little", signed = False) # u32 little endian
    p_bytes = file.read(l)
    data.append(p_bytes)

# %%
data
# Out:
# [b'{"bssid":"02:00:00:00:00:00","devicename":"TY1615","finddevicetime":0,"ip":"10.165.240.4","port":2010}']
